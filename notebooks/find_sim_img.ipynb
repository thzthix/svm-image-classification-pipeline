# %%
import cv2
import pandas as pd
import numpy as np
import heapq
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from skimage.metrics import structural_similarity as ssim

# %%
train_path = '../fashionmnist/fashion-mnist_train.csv'
private_path = './private_test_data.csv'
train = pd.read_csv(train_path)
grouped_train = train.groupby('label')
private = pd.read_csv(private_path)
train = train.drop(['label'],axis = 1)
private = private.drop(['label'],axis = 1)
print(train.shape)
print(private.shape)
# Out:
# (60000, 784)
# (15000, 784)

# %%
train=np.array(train)
train=train.reshape(60000,28,28)
train=list(train)
private=np.array(private)
private=private.reshape(15000,28,28)
private=list(private)

# %%
def cal_sim(img1, img2):
    return ssim(img1, img2, data_range=8)

# %%
#res_result = []
cross_train = set()
start = 500; end = 1000
for pri_ind in range(start,end):
    max_sim_ind = []
    img1 = private[pri_ind]
    max_sim, max_sim_ind = -1, -13
    for train_ind in range(60000):
        sim = ssim(img1, train[train_ind], data_range=8)
        if (max_sim < sim):
            max_sim = sim; max_sim_ind = train_ind
    print(f"now private index... {pri_ind}")
    #res_result.append([img1, train[max_sim_ind[0][1]]])
    cross_train.add(max_sim_ind)
# Out:
# now private index... 500
# now private index... 501
# now private index... 502
# now private index... 503
# now private index... 504
# now private index... 505
# now private index... 506
# now private index... 507
# now private index... 508
# now private index... 509
# now private index... 510
# now private index... 511
# now private index... 512
# now private index... 513
# now private index... 514
# now private index... 515
# now private index... 516
# now private index... 517
# now private index... 518
# now private index... 519
# now private index... 520
# now private index... 521
# now private index... 522
# now private index... 523
# now private index... 524
# now private index... 525
# now private index... 526
# now private index... 527
# now private index... 528
# now private index... 529
# now private index... 530
# now private index... 531
# now private index... 532
# now private index... 533
# now private index... 534
# now private index... 535
# now private index... 536
# now private index... 537
# now private index... 538
# now private index... 539
# now private index... 540
# now private index... 541
# now private index... 542
# now private index... 543
# now private index... 544
# now private index... 545
# now private index... 546
# now private index... 547
# now private index... 548
# now private index... 549
# now private index... 550
# now private index... 551
# now private index... 552
# now private index... 553
# now private index... 554
# now private index... 555
# now private index... 556
# now private index... 557
# now private index... 558
# now private index... 559
# now private index... 560
# now private index... 561
# now private index... 562
# now private index... 563
# now private index... 564
# now private index... 565
# now private index... 566
# now private index... 567
# now private index... 568
# now private index... 569
# now private index... 570
# now private index... 571
# now private index... 572
# now private index... 573
# now private index... 574
# now private index... 575
# now private index... 576
# now private index... 577
# now private index... 578
# now private index... 579
# now private index... 580
# now private index... 581
# now private index... 582
# now private index... 583
# now private index... 584
# now private index... 585
# now private index... 586
# now private index... 587
# now private index... 588
# now private index... 589
# now private index... 590
# now private index... 591
# now private index... 592
# now private index... 593
# now private index... 594
# now private index... 595
# now private index... 596
# now private index... 597
# now private index... 598
# now private index... 599
# now private index... 600
# now private index... 601
# now private index... 602
# now private index... 603
# now private index... 604
# now private index... 605
# now private index... 606
# now private index... 607
# now private index... 608
# now private index... 609
# now private index... 610
# now private index... 611
# now private index... 612
# now private index... 613
# now private index... 614
# now private index... 615
# now private index... 616
# now private index... 617
# now private index... 618
# now private index... 619
# now private index... 620
# now private index... 621
# now private index... 622
# now private index... 623
# now private index... 624
# now private index... 625
# now private index... 626
# now private index... 627
# now private index... 628
# now private index... 629
# now private index... 630
# now private index... 631
# now private index... 632
# now private index... 633
# now private index... 634
# now private index... 635
# now private index... 636
# now private index... 637
# now private index... 638
# now private index... 639
# now private index... 640
# now private index... 641
# now private index... 642
# now private index... 643
# now private index... 644
# now private index... 645
# now private index... 646
# now private index... 647
# now private index... 648
# now private index... 649
# now private index... 650
# now private index... 651
# now private index... 652
# now private index... 653
# now private index... 654
# now private index... 655
# now private index... 656
# now private index... 657
# now private index... 658
# now private index... 659
# now private index... 660
# now private index... 661
# now private index... 662
# now private index... 663
# now private index... 664
# now private index... 665
# now private index... 666
# now private index... 667
# now private index... 668
# now private index... 669
# now private index... 670
# now private index... 671
# now private index... 672
# now private index... 673
# now private index... 674
# now private index... 675
# now private index... 676
# now private index... 677
# now private index... 678
# now private index... 679
# now private index... 680
# now private index... 681
# now private index... 682
# now private index... 683
# now private index... 684
# now private index... 685
# now private index... 686
# now private index... 687
# now private index... 688
# now private index... 689
# now private index... 690
# now private index... 691
# now private index... 692
# now private index... 693
# now private index... 694
# now private index... 695
# now private index... 696
# now private index... 697
# now private index... 698
# now private index... 699
# now private index... 700
# now private index... 701
# now private index... 702
# now private index... 703
# now private index... 704
# now private index... 705
# now private index... 706
# now private index... 707
# now private index... 708
# now private index... 709
# now private index... 710
# now private index... 711
# now private index... 712
# now private index... 713
# now private index... 714
# now private index... 715
# now private index... 716
# now private index... 717
# now private index... 718
# now private index... 719
# now private index... 720
# now private index... 721
# now private index... 722
# now private index... 723
# now private index... 724
# now private index... 725
# now private index... 726
# now private index... 727
# now private index... 728
# now private index... 729
# now private index... 730
# now private index... 731
# now private index... 732
# now private index... 733
# now private index... 734
# now private index... 735
# now private index... 736
# now private index... 737
# now private index... 738
# now private index... 739
# now private index... 740
# now private index... 741
# now private index... 742
# now private index... 743
# now private index... 744
# now private index... 745
# now private index... 746
# now private index... 747
# now private index... 748
# now private index... 749
# now private index... 750
# now private index... 751
# now private index... 752
# now private index... 753
# now private index... 754
# now private index... 755
# now private index... 756
# now private index... 757
# now private index... 758
# now private index... 759
# now private index... 760
# now private index... 761
# now private index... 762
# now private index... 763
# now private index... 764
# now private index... 765
# now private index... 766
# now private index... 767
# now private index... 768
# now private index... 769
# now private index... 770
# now private index... 771
# now private index... 772
# now private index... 773
# now private index... 774
# now private index... 775
# now private index... 776
# now private index... 777
# now private index... 778
# now private index... 779
# now private index... 780
# now private index... 781
# now private index... 782
# now private index... 783
# now private index... 784
# now private index... 785
# now private index... 786
# now private index... 787
# now private index... 788
# now private index... 789
# now private index... 790
# now private index... 791
# now private index... 792
# now private index... 793
# now private index... 794
# now private index... 795
# now private index... 796
# now private index... 797
# now private index... 798
# now private index... 799
# now private index... 800
# now private index... 801
# now private index... 802
# now private index... 803
# now private index... 804
# now private index... 805
# now private index... 806
# now private index... 807
# now private index... 808
# now private index... 809
# now private index... 810
# now private index... 811
# now private index... 812
# now private index... 813
# now private index... 814
# now private index... 815
# now private index... 816
# now private index... 817
# now private index... 818
# now private index... 819
# now private index... 820
# now private index... 821
# now private index... 822
# now private index... 823
# now private index... 824
# now private index... 825
# now private index... 826
# now private index... 827
# now private index... 828
# now private index... 829
# now private index... 830
# now private index... 831
# now private index... 832
# now private index... 833
# now private index... 834
# now private index... 835
# now private index... 836
# now private index... 837
# now private index... 838
# now private index... 839
# now private index... 840
# now private index... 841
# now private index... 842
# now private index... 843
# now private index... 844
# now private index... 845
# now private index... 846
# now private index... 847
# now private index... 848
# now private index... 849
# now private index... 850
# now private index... 851
# now private index... 852
# now private index... 853
# now private index... 854
# now private index... 855
# now private index... 856
# now private index... 857
# now private index... 858
# now private index... 859
# now private index... 860
# now private index... 861
# now private index... 862
# now private index... 863
# now private index... 864
# now private index... 865
# now private index... 866
# now private index... 867
# now private index... 868
# now private index... 869
# now private index... 870
# now private index... 871
# now private index... 872
# now private index... 873
# now private index... 874
# now private index... 875
# now private index... 876
# now private index... 877
# now private index... 878
# now private index... 879
# now private index... 880
# now private index... 881
# now private index... 882
# now private index... 883
# now private index... 884
# now private index... 885
# now private index... 886
# now private index... 887
# now private index... 888
# now private index... 889
# now private index... 890
# now private index... 891
# now private index... 892
# now private index... 893
# now private index... 894
# now private index... 895
# now private index... 896
# now private index... 897
# now private index... 898
# now private index... 899
# now private index... 900
# now private index... 901
# now private index... 902
# now private index... 903
# now private index... 904
# now private index... 905
# now private index... 906
# now private index... 907
# now private index... 908
# now private index... 909
# now private index... 910
# now private index... 911
# now private index... 912
# now private index... 913
# now private index... 914
# now private index... 915
# now private index... 916
# now private index... 917
# now private index... 918
# now private index... 919
# now private index... 920
# now private index... 921
# now private index... 922
# now private index... 923
# now private index... 924
# now private index... 925
# now private index... 926
# now private index... 927
# now private index... 928
# now private index... 929
# now private index... 930
# now private index... 931
# now private index... 932
# now private index... 933
# now private index... 934
# now private index... 935
# now private index... 936
# now private index... 937
# now private index... 938
# now private index... 939
# now private index... 940
# now private index... 941
# now private index... 942
# now private index... 943
# now private index... 944
# now private index... 945
# now private index... 946
# now private index... 947
# now private index... 948
# now private index... 949
# now private index... 950
# now private index... 951
# now private index... 952
# now private index... 953
# now private index... 954
# now private index... 955
# now private index... 956
# now private index... 957
# now private index... 958
# now private index... 959
# now private index... 960
# now private index... 961
# now private index... 962
# now private index... 963
# now private index... 964
# now private index... 965
# now private index... 966
# now private index... 967
# now private index... 968
# now private index... 969
# now private index... 970
# now private index... 971
# now private index... 972
# now private index... 973
# now private index... 974
# now private index... 975
# now private index... 976
# now private index... 977
# now private index... 978
# now private index... 979
# now private index... 980
# now private index... 981
# now private index... 982
# now private index... 983
# now private index... 984
# now private index... 985
# now private index... 986
# now private index... 987
# now private index... 988
# now private index... 989
# now private index... 990
# now private index... 991
# now private index... 992
# now private index... 993
# now private index... 994
# now private index... 995
# now private index... 996
# now private index... 997
# now private index... 998
# now private index... 999

# %%
'''
for i in range(len(res_result)):
    image1, image2 = res_result[i]
    gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1])

    # 첫 번째 이미지 표시
    ax0 = plt.subplot(gs[0])
    ax0.imshow(image1, cmap='gray')
    ax0.set_title('Private img')
    ax0.axis('off')
    ax1 = plt.subplot(gs[1])
    ax1.imshow(image2, cmap='gray')
    ax1.set_title('Train img')
    ax1.axis('off')
    # 이미지 간의 간격 조정
    plt.tight_layout()

    # 플롯 보여주기
    plt.show()
'''

# %%
cross_train = list(cross_train)
with open(f'./{start}~{end}결과.txt', 'w') as file:
        for i in range(len(cross_train)):
            file.write(f"{cross_train[i]}\n")

# %% [markdown]
# - .txt 파일들 하나로 교집합하기

# %%
file_lst = ["0~500결과", "500~1000결과", "1000~2000결과","2000~4000결과", "4000~6000결과", "6000~10000결과",
            "10000~12500결과", "12500~14112결과", "14112~15000결과"] #"
result_set = set()
for file_name in file_lst:
    with open(f"{file_name}.txt", 'r') as file:
        for ind in file.readlines():
            result_set.add(int(ind))
print(len(result_set))
result_set = list(result_set)
with open(f'./결과통합.txt', 'w') as file:
        for i in range(len(result_set)):
            file.write(f"{result_set[i]}\n")
# Out:
# 9414
